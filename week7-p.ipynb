# %%
import requests
from bs4 import BeautifulSoup

r = requests.get("https://www.ptt.cc/bbs/Japandrama/index.html") #將網頁資料GET下來
soup = BeautifulSoup(r.text,"html.parser") #將網頁資料以html.parser
sel = soup.select("div.title a") #取HTML標中的 <div class="title"></div> 中的<a>標籤存入sel
for s in sel:
    print(s["href"], s.text)
# Out:
# /bbs/Japandrama/M.1667219517.A.C9B.html [閒聊] (雷) 展翅飛舞 第五週21 想飛上藍天
# /bbs/Japandrama/M.1667233838.A.989.html [閒聊] 真相在耳中 ep02  (雷)
# /bbs/Japandrama/M.1667239977.A.F13.html [情報] 瀧澤辭去J社副社長並退社、井ノ原接任J
# /bbs/Japandrama/M.1667245381.A.5EA.html [地雷] 靈媒偵探城塚翡翠第三集
# /bbs/Japandrama/M.1667252704.A.59A.html [新聞] 濱田岳、若き日の江戸川乱歩役に(NHK土22
# /bbs/Japandrama/M.1667266536.A.9A6.html Re: [情報] 2022秋季檔收視報告
# /bbs/Japandrama/M.1667280100.A.CDD.html [訪談] 松下洸平 『遊戲之子』訪談
# /bbs/Japandrama/M.1667289565.A.CBD.html [LIVE] 老菜鳥 EP01
# /bbs/Japandrama/M.1667289642.A.D3A.html [LIVE] 鋼盔男兒 EP07
# /bbs/Japandrama/M.1667293409.A.BDD.html [情報] KKTV 獨家跟播 《自行車店的高橋》
# /bbs/Japandrama/M.1667296627.A.D97.html Re: [新聞] 北川景子、月9初主演で新米教師役
# /bbs/Japandrama/M.1667296858.A.91A.html [閒聊] (雷) 展翅飛舞 第五週22 想飛上藍天
# /bbs/Japandrama/M.1667298346.A.EC1.html [公告] 2022年11月份違規處理暨板務交流區
# /bbs/Japandrama/M.1667298433.A.99F.html [公告] 置底閒聊區 (2022秋 第二篇)
# /bbs/Japandrama/M.1636548328.A.0AE.html [公告] 日劇板板規 2021.11.10
# ...

# %%
import requests
from bs4 import BeautifulSoup
url = "https://www.ptt.cc/bbs/Japandrama/index.html"
for i in range(6): #往上爬3頁
    r = requests.get(url)
    soup = BeautifulSoup(r.text,"html.parser")
    sel = soup.select("div.title a") #標題
    u = soup.select("div.btn-group.btn-group-paging a") #a標籤
    url = "https://www.ptt.cc"+ u[1]["href"] #上一頁的網址

for s in sel: #印出網址跟標題
    print(s["href"],s.text)
# Out:
# /bbs/Japandrama/M.1666489733.A.310.html [閒聊] 真相在耳中 ep01 （真相は耳の中） (雷)
# /bbs/Japandrama/M.1666502294.A.529.html [情報] Netflix「舞伎家的料理人」劇照公開
# /bbs/Japandrama/M.1666503388.A.425.html [閒聊] Japanese Style 第一集
# /bbs/Japandrama/M.1666515338.A.2D4.html [LIVE] 鎌倉殿的13人 第40集(台灣 7PM)
# /bbs/Japandrama/M.1666520549.A.2BC.html [地雷] 一橋桐子的犯罪日記
# /bbs/Japandrama/M.1666538929.A.789.html Re: [情報] KKTV《孤獨的美食家》松重豐 訪問
# /bbs/Japandrama/M.1666553966.A.0A5.html [新聞] 妻夫木聡、来年１月期日曜劇場 藤原竜也
# /bbs/Japandrama/M.1666558066.A.08A.html [新聞] 北川景子、月9初主演で新米教師役
# /bbs/Japandrama/M.1666573921.A.288.html Re: [情報] 2022秋季檔收視報告
# /bbs/Japandrama/M.1666575710.A.3E9.html Re: [情報] 22'秋冬晨間《飛舞！》收視報告
# /bbs/Japandrama/M.1666587324.A.DBB.html [新聞] 野木亜紀子脚本『連続ドラマW フェンス』
# /bbs/Japandrama/M.1666595830.A.494.html [心得] 遊戲之子 EP01 覺得好看!
# /bbs/Japandrama/M.1666598364.A.868.html [LIVE] 鋼盔男兒 EP01
# /bbs/Japandrama/M.1666598498.A.FAC.html [LIVE] 公平交易英雄 EP06
# /bbs/Japandrama/M.1666602117.A.7E3.html [閒聊] (雷) 展翅飛舞 第四週16 乘載青春的翅膀
# ...

# %%
import pandas as pd

titles = [r.find('div',"title").text.strip() for r in rents]

dict = {"address":a,"title":t}

df = pd.DataFrame(dict)

print(df)
# Out:
#                                    address                   title
# 0  /bbs/Japandrama/M.1667298433.A.99F.html  [公告] 置底閒聊區 (2022秋 第二篇)

# %%
import csv
def writeCsv(filename, dataList):
    with open(filename+'.csv', 'w', newline='') as csvfile:
        # 定義欄位
        fieldnames = ['q', 'a', 'url']

        # 將 dictionary 寫入 CSV 檔
        writer = csv.DictWriter(csvfile, fieldnames=fieldnames)

        # 寫入第一列的欄位名稱
        writer.writeheader()

        # 寫入資料
        for qa in dataList:
            writer.writerow(qa)

# %%
import csv

with open("ptt.csv","w",newline="") as f:
    writer = csv.writer(f)
    writer.writerow(['網址','標題',])

    writer.writerow([s["href"],s.text])

# %%
import pandas as pd
pttcsv = pd.read_csv("ptt.csv")
pttcsv
# Out:
#     Unnamed: 0                               標題     日期
# 0            0         [討論] 民放黃金檔連續劇平均收視 歷代倒數排名  10/28
# 1            1     [情報] 客家電視台 11/23起22點重播《半澤直樹》  10/28
# 2            2                 [LIVE] 鋼盔男兒 EP05  10/28
# 3            3               [LIVE] 公平交易英雄 EP10  10/28
# 4            4      [閒聊] (雷) 展翅飛舞 第四週20 乘載青春的翅膀  10/28
# 5            5               [心得] Silent第四集談談湊斗  10/28
# 6            6  [心得] THE TRAVEL NURSE 旅行護理師 第二集  10/28
# 7            7                 [心得] silent EP04  10/29
# 8            8  Re: [心得] Elpis-希望或是災難 ep.01 (雷)  10/29
# 9            9         [閒聊] silent第四集Tver專欄劇評翻譯  10/29
# 10          10       [訪談] 鎌倉殿的13人 坂東彌十郎(北條時政)訪談  10/29
# 11          11                 [心得] silent EP04  10/29
# 12          12                  [心得] Silent ep2  10/29
# 13          13                 [LIVE] 遊戲之子 EP02  10/29
# 14          14               [LIVE] 祈願的病歷表 EP04  10/29
# 15          15                    [心得] 詐欺獵人 ep2  10/29
# ...
