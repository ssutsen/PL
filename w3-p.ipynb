# %%
import pandas as pd

#read csv file
data1=pd.read_csv("YouBike.csv")
print(data1)
# Out:
#               sna  total  可借數 sarea  可還空位數
# 0            大鵬華城     20    6   新店區     10
# 1           汐止火車站     44    9   汐止區     35
# 2           汐止區公所     46    8   汐止區     37
# 3          國泰綜合醫院     48   32   汐止區     16
# 4    捷運大坪林站(5號出口)     46   20   新店區     26
# ..            ...    ...  ...   ...    ...
# 648        中山溫泉公園     44   17   金山區     23
# 649         龍米停車場     30   13   八里區     17
# 650          雙和醫院     30    6   中和區     21
# 651      寶高智慧產業園區     60   11   新店區     42
# 652   捷運三重站(1號出口)     40   29   三重區     11
#
# [653 rows x 5 columns]

# %%
#顯示前n筆資料
data1.head(3)
# Out:
#      sna  total  可借數 sarea  可還空位數
# 0   大鵬華城     20    6   新店區     10
# 1  汐止火車站     44    9   汐止區     35
# 2  汐止區公所     46    8   汐止區     37

# %%
#顯示後n筆資料
data1.tail(3)
# Out:
#              sna  total  可借數 sarea  可還空位數
# 650         雙和醫院     30    6   中和區     21
# 651     寶高智慧產業園區     60   11   新店區     42
# 652  捷運三重站(1號出口)     40   29   三重區     11

# %%
df = pd.DataFrame(data1)

print(df)
# Out:
#               sna  total  可借數 sarea  可還空位數
# 0            大鵬華城     20    6   新店區     10
# 1           汐止火車站     44    9   汐止區     35
# 2           汐止區公所     46    8   汐止區     37
# 3          國泰綜合醫院     48   32   汐止區     16
# 4    捷運大坪林站(5號出口)     46   20   新店區     26
# ..            ...    ...  ...   ...    ...
# 648        中山溫泉公園     44   17   金山區     23
# 649         龍米停車場     30   13   八里區     17
# 650          雙和醫院     30    6   中和區     21
# 651      寶高智慧產業園區     60   11   新店區     42
# 652   捷運三重站(1號出口)     40   29   三重區     11
#
# [653 rows x 5 columns]

# %%
new_df = df.sort_values(["total"], ascending=True)
print("遞增排序")
print(new_df)
# Out:
# 遞增排序
#               sna  total  可借數 sarea  可還空位數
# 516          重慶國小     14    7   板橋區      7
# 322         猴硐火車站     14    3   瑞芳區     11
# 90         建國民權路口     14   10   新店區     17
# 385      民族二街明峰街口     16    5   汐止區      9
# 639         深坑雲鄉路     16    6   深坑區      4
# ..            ...    ...  ...   ...    ...
# 92          捷運蘆洲站     92   34   蘆洲區     56
# 521   捷運新埔站(1號出口)     94    0   板橋區     94
# 160        民生長江路口    100   44   板橋區     56
# 105   捷運板橋站(1號出口)    102    2   板橋區    100
# 274  捷運頭前庄站(1號出口)    114   56   新莊區     57
#
# [653 rows x 5 columns]

# %%
sourse=list(df["sarea"])
print(sourse)
# Out:
# ['新店區', '汐止區', '汐止區', '汐止區', '新店區', '汐止區', '三重區', '三重區', '三重區', '汐止區', '汐止區', '汐止區', '汐止區', '新莊區', '新莊區', '新莊區', '新店區', '蘆洲區', '三重區', '三重區', '三重區', '新莊區', '汐止區', '汐止區', '中和區', '中和區', '永和區', '中和區', '汐止區', '蘆洲區', '蘆洲區', '蘆洲區', '新莊區', '新店區', '新店區', '新莊區', '永和區', '永和區', '永和區', '新店區', '永和區', '永和區', '新店區', '新店區', '新莊區', '新莊區', '三重區', '新莊區', '汐止區', '新店區', '永和區', '新店區', '新店區', '新店區', '汐止區', '汐止區', '汐止區', '汐止區', '汐止區', '永和區', '汐止區', '新店區', '三重區', '汐止區', '三重區', '三重區', '三重區', '三重區', '三重區', '新莊區', '永和區', '新莊區', '三重區', '三重區', '蘆洲區', '新莊區', '三重區', '三重區', '中和區', '新莊區', '蘆洲區', '三重區', '三重區', '三重區', '新店區', '永和區', '蘆洲區', '蘆洲區', '新莊區', '新莊區', '新店區', '三重區', '蘆洲區', '三重區', '板橋區', '板橋區', '板橋區', '板橋區', '新店區', '新店區', '板橋區', '板橋區', '板橋區', '板橋區', '板橋區', '板橋區', '板橋區', '板橋區', '板橋區', '三重區', '三重區', '三重區', '新莊區', '新莊區', '板橋區', '新莊區', '永和區', '三重區', '三重區', '三重區', '汐止區', '中和區', '蘆洲區', '板橋區', '三重區', '泰山區', '蘆洲區', '新莊區', '三重區', '新店區', '新莊區', '板橋區', '新莊區', '板橋區', '板橋區', '板橋區', '泰山區', '板橋區', '新莊區', '板橋區', '板橋區', '土城區', '三重
# ...
