# %%
import jieba
import jieba.analyse
import pandas as pd
import numpy
from collections import Counter

# %%
orgdata = pd.read_csv('activity.csv')
orgdata.head()
# Out:
#                      Id             Name  \
# 0  C2_315080000H_080675      2022基隆潮境海灣節
# 1  C2_315080000H_080676        2022基隆潮藝術
# 2  C2_315080000H_080677  2022竹子湖海芋季及繡球花季
# 3  C2_315080000H_080678       新北市貢寮海洋音樂祭
# 4  C2_315080000H_080679        2022新北萬里蟹
#
#                                          Description Participation Location  \
# 0  望海巷潮境海灣，範圍自環保復育公園海岬至深澳岬之海域，面積約250公頃，海灣山海景觀秀麗、生...           NaN  基隆市 中正區
# 1  「潮藝術」視在地居民的智慧及生活為藝術，也讓藝術成為問題性，一場與自然共生的大地藝術祭在裝點...           NaN  基隆市 中正區
# 2  竹子湖海拔670公尺，位居大屯山、七星山與小觀音山間的谷地。曾是火山堰塞湖，湖水退去後留下肥...           NaN  臺北市 北投區
# 3  「貢寮海洋音樂祭」起始於民國99年（西元2010年），係爲豐富新北市的海洋文化性格、建立貢寮...           NaN  新北市 貢寮區
# 4  本市每年訂於9月辦理萬里蟹產季起跑記者會，除宣告萬里蟹產季正式到來，並預告10月至12月即將...           NaN  新北市 萬里區
#
#          Add Region Town  Tel         Org  ...  \
# 0       碧砂漁港    基隆市  中正區  NaN       基隆市政府  ...
# 1       正濱漁港    基隆市  中正區  NaN    基隆市政府文化局  ...
# 2  竹子湖路1之20號    臺北市  北投區  NaN  臺北市政府產業發展局  ...
# 3  福隆里興隆街40號    新北市  貢寮區  NaN       新北市政府  ...
# 4       野柳漁港    新北市  萬里區  NaN       新北市政府  ...
#
#                        Picdescribe3          Px         Py Class1 Class2  Map  \
# 0      基隆潮境海灣節－潮海洋：基隆國際帆船賽暨台琉國際帆船賽。  121.786290  25.147141      1    2.0  NaN
# 1            Martens Visser〈HOLONS〉  121.766055  25.151951      1    2.0  NaN
# 2  竹子湖海芋季及繡球花季，農園中的地景藝術為農友親自打造，別具特色  121.536788  25.175495      1    2.0  NaN
# 3                       冒險台表演與熱情的觀眾  121.943158  25.021998      1    2.0  NaN
# 4         參加活動民眾皆配合防疫規定戴口罩，購買螃蟹熱情不減  121.687063  25.205871      1    2.0  NaN
#
#   Travellinginfo Parkinginfo Charge Remarks
# 0            NaN         NaN    NaN     NaN
# 1            NaN         NaN    NaN     NaN
# 2            NaN         NaN    NaN     NaN
# 3            NaN         NaN    NaN     NaN
# 4            NaN         NaN    NaN     NaN
#
# [5 rows x 30 columns]

# %%
orgdata['seg'] = ""
orgdata.head()
# Out:
#                      Id             Name  \
# 0  C2_315080000H_080675      2022基隆潮境海灣節
# 1  C2_315080000H_080676        2022基隆潮藝術
# 2  C2_315080000H_080677  2022竹子湖海芋季及繡球花季
# 3  C2_315080000H_080678       新北市貢寮海洋音樂祭
# 4  C2_315080000H_080679        2022新北萬里蟹
#
#                                          Description Participation Location  \
# 0  望海巷潮境海灣，範圍自環保復育公園海岬至深澳岬之海域，面積約250公頃，海灣山海景觀秀麗、生...           NaN  基隆市 中正區
# 1  「潮藝術」視在地居民的智慧及生活為藝術，也讓藝術成為問題性，一場與自然共生的大地藝術祭在裝點...           NaN  基隆市 中正區
# 2  竹子湖海拔670公尺，位居大屯山、七星山與小觀音山間的谷地。曾是火山堰塞湖，湖水退去後留下肥...           NaN  臺北市 北投區
# 3  「貢寮海洋音樂祭」起始於民國99年（西元2010年），係爲豐富新北市的海洋文化性格、建立貢寮...           NaN  新北市 貢寮區
# 4  本市每年訂於9月辦理萬里蟹產季起跑記者會，除宣告萬里蟹產季正式到來，並預告10月至12月即將...           NaN  新北市 萬里區
#
#          Add Region Town  Tel         Org  ...          Px         Py Class1  \
# 0       碧砂漁港    基隆市  中正區  NaN       基隆市政府  ...  121.786290  25.147141      1
# 1       正濱漁港    基隆市  中正區  NaN    基隆市政府文化局  ...  121.766055  25.151951      1
# 2  竹子湖路1之20號    臺北市  北投區  NaN  臺北市政府產業發展局  ...  121.536788  25.175495      1
# 3  福隆里興隆街40號    新北市  貢寮區  NaN       新北市政府  ...  121.943158  25.021998      1
# 4       野柳漁港    新北市  萬里區  NaN       新北市政府  ...  121.687063  25.205871      1
#
#   Class2  Map Travellinginfo Parkinginfo Charge Remarks seg
# 0    2.0  NaN            NaN         NaN    NaN     NaN
# 1    2.0  NaN            NaN         NaN    NaN     NaN
# 2    2.0  NaN            NaN         NaN    NaN     NaN
# 3    2.0  NaN            NaN         NaN    NaN     NaN
# 4    2.0  NaN            NaN         NaN    NaN     NaN
#
# [5 rows x 31 columns]

# %%
jieba.analyse.set_stop_words('stopwords.txt')
index = 0
for documents in orgdata['content']:
    seg_list = jieba.analyse.extract_tags(documents, 150)
    #seg_list = jieba.lcut(documents)
    orgdata['seg'].iloc[index] = seg_list
    index += 1

orgdata['seg']
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File c:\Users\babe9\AppData\Local\Programs\Python\Python310\lib\site-packages\pandas\core\indexes\base.py:3800, in Index.get_loc(self, key, method, tolerance)
#    3799 try:
# -> 3800     return self._engine.get_loc(casted_key)
#    3801 except KeyError as err:
#
# File c:\Users\babe9\AppData\Local\Programs\Python\Python310\lib\site-packages\pandas\_libs\index.pyx:138, in pandas._libs.index.IndexEngine.get_loc()
#
# File c:\Users\babe9\AppData\Local\Programs\Python\Python310\lib\site-packages\pandas\_libs\index.pyx:165, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas\_libs\hashtable_class_helper.pxi:5745, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas\_libs\hashtable_class_helper.pxi:5753, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'content'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# Cell In [6], line 3
#       1 jieba.analyse.set_stop_words('stopwords.txt')
#       2 index = 0
# ----> 3 for documents in orgdata['content']:
#       4     seg_list = jieba.analyse.extract_tags(documents, 150)
#       5     #seg_list = jieba.lcut(documents)
#
# File c:\Users\babe9\AppData\Local\Programs\Python\Python310\lib\site-packages\pandas\core\frame.py:3805, in DataFrame.__getitem__(self, key)
#    3803 if self.columns.nlevels > 1:
#    3804     return self._getitem_multilevel(key)
# -> 3805 indexer = self.columns.get_loc(key)
#    3806 if is_integer(indexer):
#    3807     indexer = [indexer]
#
# File c:\Users\babe9\AppData\Local\Programs\Python\Python310\lib\site-packages\pandas\core\indexes\base.py:3802, in Index.get_loc(self, key, method, tolerance)
#    3800     return self._engine.get_loc(casted_key)
#    3801 except KeyError as err:
# -> 3802     raise KeyError(key) from err
#    3803 except TypeError:
#    3804     # If we have a listlike key, _check_indexing_error will raise
#    3805     #  InvalidIndexError. Otherwise we fall through and re-raise
#    3806     #  the TypeError.
#    3807     self._check_indexing_error(key)
#
# KeyError: 'content'
